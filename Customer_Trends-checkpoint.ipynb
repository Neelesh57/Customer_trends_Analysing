# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("shopping_trends.csv")
df.sample(10)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 35             36   54    Male         Blouse     Clothing
# 176           177   53    Male       Backpack  Accessories
# 2997         2998   41  Female        Sweater     Clothing
# 800           801   32    Male          Socks     Clothing
# 1056         1057   20    Male        Sweater     Clothing
# 2852         2853   40  Female           Belt  Accessories
# 127           128   24    Male        Sweater     Clothing
# 1098         1099   49    Male        Handbag  Accessories
# 1452         1453   60    Male         Jacket    Outerwear
# 3501         3502   53  Female          Shoes     Footwear
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 35                       33  Massachusetts    M       Cyan  Summer
# 176                      81  New Hampshire    L      Black  Spring
# 2997                     40          Idaho    S     Yellow  Spring
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
df.shape
# Out:
# (3900, 19)

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
plt.figure(figsize = (10, 6))
ax = df["Gender"].value_counts().plot(kind = 'bar', color=['blue', '#FF69B4'],rot = 0)
ax.set_xticklabels(('Male', 'Female'))
for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+0.25, p.get_height()), ha = 'center', color = 'black')
    ax.tick_params(axis = 'both', labelsize = 15)
plt.xlabel('Gender',color='black')
plt.ylabel('Counts');

# %%
plt.figure(figsize=(15,6))
counts=df['Gender'].value_counts()
plt.title("Males vs Females")
plt.legend(labels=counts.index,loc='best')
plt.xlabel('Gender')
plt.ylabel('Counts')
counts.plot(kind='pie',explode=(0,0.1),autopct='%.1f%%')
plt.show()

# %% [markdown]
# # AGE DISTRIBUTION

# %%
fig,ax=plt.subplots(figsize=(15,8))

ax.hist(df["Age"], bins=25, edgecolor='black',alpha=0.4,color="skyblue",density=True)
df['Age'].plot(kind='kde',color='red')

ax.set_xlabel('Age')
ax.set_ylabel('count')
ax.set_title('Age Distribution Histogram with Density Curve')

ax.legend(['Density Curve','Histogram'])
plt.show()

# %% [markdown]
# Items Categories

# %%
df['Category'].value_counts()
# Out:
# Category
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: count, dtype: int64

# %%
plt.figure(figsize = (20, 10))

ax = df["Category"].value_counts().plot(kind = 'bar',  rot = 0)
ax.set_xticklabels(('Clothing', 'Accessories', 'Footwear', 'Outerwear'))

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
    ax.tick_params(axis = 'both', labelsize = 15)
    
plt.xlabel('Item Gategory', weight = "bold", color = "#D71313", fontsize = 14, labelpad = 20)
plt.ylabel('Counts', weight = "bold", color = "#D71313", fontsize = 14, labelpad = 20);

# %%
plt.figure(figsize = (20, 6))
counts = df["Category"].value_counts()
explode = (0, 0.0, 0.0, 0.1)
counts.plot(kind = 'pie', fontsize = 12, explode = explode, autopct = '%.1f%%')
plt.xlabel('Category', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.axis('equal')
plt.legend(labels = counts.index, loc = "best")
plt.show()

# %%
df["Item Purchased"].value_counts()
# Out:
# Item Purchased
# Blouse        171
# Jewelry       171
# Pants         171
# Shirt         169
# Dress         166
# Sweater       164
# Jacket        163
# Belt          161
# Sunglasses    161
# Coat          161
# Sandals       160
# Socks         159
# Skirt         158
# Shorts        157
# Scarf         157
# Hat           154
# Handbag       153
# Hoodie        151
# Shoes         150
# T-shirt       147
# Sneakers      145
# Boots         144
# Backpack      143
# Gloves        140
# Jeans         124
# Name: count, dtype: int64

# %%
plt.figure(figsize=(18,8))
df["Item Purchased"].value_counts().sort_values(ascending = True).plot(kind='barh',edgecolor='black',color = sns.color_palette('tab20'))
plt.xlabel('counts',fontsize=15)
plt.ylabel('Item Purchased',fontsize=15)
plt.title('Item Purchased', fontsize = 16)
plt.xticks(rotation = 0, ha = 'center', fontsize = 16)
plt.show()

# %%
df['Location'].value_counts()
# Out:
# Location
# Montana           96
# California        95
# Idaho             93
# Illinois          92
# Alabama           89
# Minnesota         88
# Nebraska          87
# New York          87
# Nevada            87
# Maryland          86
# Delaware          86
# Vermont           85
# Louisiana         84
# North Dakota      83
# Missouri          81
# West Virginia     81
# New Mexico        81
# Mississippi       80
# Indiana           79
# Georgia           79
# Kentucky          79
# Arkansas          79
# North Carolina    78
# Connecticut       78
# Virginia          77
# Ohio              77
# Tennessee         77
# Texas             77
# Maine             77
# South Carolina    76
# Colorado          75
# Oklahoma          75
# Wisconsin         75
# Oregon            74
# Pennsylvania      74
# Washington        73
# Michigan          73
# Alaska            72
# Massachusetts     72
# Wyoming           71
# Utah              71
# New Hampshire     71
# South Dakota      70
# ...

# %%
plt.figure(figsize=(15,8))
df['Location'].value_counts().plot(kind='bar',color=sns.color_palette('tab20'))
plt.xlabel('Location',color = "#D71313", fontsize = 15)
plt.ylabel('Counts',color = "#D71313", fontsize = 15)
plt.show()

# %%
df['Size'].value_counts()
# Out:
# Size
# M     1755
# L     1053
# S      663
# XL     429
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,8))
ax=df['Size'].value_counts().plot(kind='bar',color=sns.color_palette("husl", 8),rot=0)
plt.xlabel('Size',fontsize=15,weight='bold')
plt.ylabel('Count',fontsize=15,weight='bold')
for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
    ax.tick_params(axis = 'both', labelsize = 15)

plt.show()

# %%
plt.figure(figsize=(15,8))
ax=df['Season'].value_counts().plot(kind='bar',color=sns.color_palette("tab10"),rot=0)
plt.xlabel('Season',fontsize=15,weight='bold')
plt.ylabel('Count',fontsize=15,weight='bold')
for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
    ax.tick_params(axis = 'both', labelsize = 15)

plt.show()

# %%
plt.figure(figsize=(15,8))
counts=df['Season'].value_counts()
explode=[0,0,0,0.1]
counts.plot(kind='pie',explode=explode,autopct='%0.1f%%')
plt.xlabel("Season",fontsize=15)
plt.axis('equal')
plt.legend(labels=counts.index,loc='best')
plt.show()

# %%
df["Subscription Status"].value_counts()
# Out:
# Subscription Status
# No     2847
# Yes    1053
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,8))
ax=df['Subscription Status'].value_counts().plot(kind='bar',color=sns.color_palette("tab10"),rot=0)
plt.xlabel('Subscription Status',fontsize=15,weight='bold')
plt.ylabel('Count',fontsize=15,weight='bold')
for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
    ax.tick_params(axis = 'both', labelsize = 15)

plt.show()

# %%
plt.figure(figsize = (15, 8))
counts = df["Subscription Status"].value_counts()
explode = (0, 0.1)
counts.plot(kind='pie',explode=explode,autopct='%1.1f%%')
plt.axis('equal')
plt.legend(labels = counts.index, loc = "best")
plt.show()

# %%
df["Payment Method"].value_counts()
# Out:
# Payment Method
# Credit Card      696
# Venmo            653
# Cash             648
# PayPal           638
# Debit Card       633
# Bank Transfer    632
# Name: count, dtype: int64

# %%
plt.figure(figsize = (20, 6))

ax = df["Payment Method"].value_counts().plot(kind = 'bar', color =sns.color_palette("Paired"), rot = 0)
ax.set_xticklabels(('Credit Card', 'Venmo', 'Cash', 'Paypal', 'Debit Card', 'Bank Transfer'))

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
    ax.tick_params(axis = 'both', labelsize = 15)
plt.xlabel("Payment Method",fontsize=15)
plt.ylabel("Count",fontsize=15)
plt.show()

# %%
plt.figure(figsize = (20, 6))
counts = df["Payment Method"].value_counts()
explode = (0, 0, 0, 0, 0.0, 0.06)
counts.plot(kind = 'pie', fontsize = 12, explode = explode, autopct = '%.1f%%')
plt.xlabel('Size', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.axis('equal')
plt.legend(labels = counts.index, loc = "best")
plt.show()

# %%
df["Shipping Type"].value_counts()
# Out:
# Shipping Type
# Free Shipping     675
# Standard          654
# Store Pickup      650
# Next Day Air      648
# Express           646
# 2-Day Shipping    627
# Name: count, dtype: int64

# %%
plt.figure(figsize = (15, 8))

ax = df["Shipping Type"].value_counts().plot(kind = 'bar', color = sns.color_palette("rocket"), rot = 0)
ax.set_xticklabels(('Free Shipping', 'Standard', 'Store Pickup', 'Next Day Air', 'Express', '2-Day Shipping'))

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
    ax.tick_params(axis = 'both', labelsize = 15)
plt.xlabel("Shipping Type",fontsize=17)
plt.show()

# %%
plt.figure(figsize = (20, 6))
counts = df["Shipping Type"].value_counts()
explode = (0, 0, 0, 0, 0.0, 0.06)
counts.plot(kind = 'pie', fontsize = 12, explode = explode, autopct = '%1.1f%%')
plt.xlabel('Shipping Type', weight = "bold", color = "#2F0F5D", fontsize = 14)
plt.axis('equal')
plt.legend(labels = counts.index, loc = "best")
plt.show()

# %%
df["Frequency of Purchases"].value_counts()
# Out:
# Frequency of Purchases
# Every 3 Months    584
# Annually          572
# Quarterly         563
# Monthly           553
# Bi-Weekly         547
# Fortnightly       542
# Weekly            539
# Name: count, dtype: int64

# %%
plt.figure(figsize = (20, 6))
ax = df["Frequency of Purchases"].value_counts().plot(kind = 'bar',color=sns.color_palette(),rot = 0)
ax.set_xticklabels(('Every 3 Months', 'Annually', 'Quarterly', 'Monthly', 'Bi-Weekly', 'Fortnightly', 'Weekly'))

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
    ax.tick_params(axis = 'both', labelsize = 15)
plt.xlabel('Frequency of Purchases', weight = "bold", color = "#D71313", fontsize = 14)

plt.show()

# %%
plt.figure(figsize = (20, 6))
counts = df["Frequency of Purchases"].value_counts()
explode = (0, 0, 0, 0, 0.0, 0, 0.06)
counts.plot(kind = 'pie', fontsize = 12, explode = explode, autopct = '%.1f%%')
plt.xlabel('Size', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.axis('equal')
plt.legend(labels = counts.index, loc = "best")
plt.show()

# %% [markdown]
# What is the average age of customers in the dataset ?

# %%
Average_age=df['Age'].mean()
print(f"Average_age:{Average_age}")
# Out:
# Average_age:44.06846153846154

# %% [markdown]
# What is the most common item purchased ?

# %%
most_common_item = df['Item Purchased'].mode()[0]
print("Most Common Item Purchased:", most_common_item)
# Out:
# Most Common Item Purchased: Blouse

# %% [markdown]
# What is the total purchase amount for each category

# %%
total_purchase_by_category=df.groupby('Category')['Purchase Amount (USD)'].sum()
print("Total Purchase Amount by Category:")
print(total_purchase_by_category)
# Out:
# Total Purchase Amount by Category:
# Category
# Accessories     74200
# Clothing       104264
# Footwear        36093
# Outerwear       18524
# Name: Purchase Amount (USD), dtype: int64

# %%
average_rating_male = df[df['Gender'] == 'Male']['Review Rating'].mean()
average_rating_female = df[df['Gender'] == 'Female']['Review Rating'].mean()
print("Average Review Rating for Male Customers:", average_rating_male)
print("Average Review Rating for Female Customers:", average_rating_female)
# Out:
# Average Review Rating for Male Customers: 3.7539592760180995
# Average Review Rating for Female Customers: 3.741426282051282
